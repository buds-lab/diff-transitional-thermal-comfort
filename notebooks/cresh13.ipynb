# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure

# %%
fig = Figure()
canvas = FigureCanvas(fig)
ax = fig.add_subplot(111)

# %%
def isNaN(num):
    return num != num

# %%
df = pd.read_csv ("2019-10-29_cozie_full.csv", index_col=0)
filtered_df = df.drop (columns=['clothing','lat_cozie','lon_cozie','responseSpeed_cozie','Floor','Latitude','Longitude','noise_sensing','voc_sensing','index','comfort_cozie','heartRate_cozie','light_cozie','noise_cozie','co2_sensing','humidity_sensing','light_sensing','temperature_sensing','temperature_mbient'],axis=1)
filtered_df['time'] = filtered_df['time'].apply(pd.Timestamp).dt.tz_convert('Asia/Singapore')
# Add new column to calculate duration 
filtered_df['time_duration'] = 0

# %%
grouped_users = filtered_df.groupby('user_id')

all_clusters = [] # Raw data
cluster_array = [] 
filtered_cluster_before = [] # Raw data that are clustered together according to duration
filtered_cluster_after = []

# %%
cresh01_df = grouped_users.get_group('cresh13')
thermal_cozie_ticks = [9,10,11]

# %%
# Gather all data relevant to specific user 
for index, datapoint in cresh01_df.iterrows():
    # print (data.time)
    if cluster_array == []:
        cluster_array.append(datapoint)
    else:
        if datapoint.time < last_time + pd.Timedelta(minutes=30):
            cluster_array.append(datapoint) 
        else:
            all_clusters.append(cluster_array)
            cluster_array = []
            cluster_array.append(datapoint)

    
    last_time = datapoint.time
#print (all_clusters)

# %% [markdown]
# # Keep clusters with more than a certain amount of data points

# %%
# Split the cluster up according to their timing
for i in range(len(all_clusters)):
    if (len(all_clusters[i]) > 1):
        # If have more than 1 datapoint
        tempList = all_clusters[i] # Store into tempList for splitting
        tempList2 = [] # Store all relevant datapoints in a cluster together before pushing into flitered_cluster
        nextDataPoint = []
         # Check if current datapoint is part of the cluster and room is not null
        for j in range(len(tempList)):
            space = tempList[j].Space_id

            if (j == 0):
                tempList2.append(tempList[j])
                last_time = tempList[j].time

            elif (tempList[j].time < last_time + pd.Timedelta(minutes=30)):
                tempList2.append(tempList[j])
                last_time = tempList[j].time

        filtered_cluster_before.append(tempList2)
print(filtered_cluster_before)
# Out:
# [[time             2019-10-07 11:18:13.974000+08:00
# thermal_cozie                                 NaN
# user_id                                   cresh13
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 288, dtype: object, time             2019-10-07 11:24:11.151000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 290, dtype: object, time             2019-10-07 11:40:52.354000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 292, dtype: object], [time             2019-10-07 16:54:23.269000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 391, dtype: object, time             2019-10-07 17:09:20.900000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 402, dtype: object, time             2019-10-07 17:38:04.240000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 414, dtype: object], [time             2019-10-07 19:19:53.105000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 430, dtype: object, time             2019-10-07 19:39:14.816000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 434, dtype: object], [time             2019-10-07 22:43:46.367000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 443, dtype: object, time             2019-10-07 23:07:10.780000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 445, dtype: object, time             2019-10-07 23:28:36.989000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 447, dtype: object], [time             2019-10-08 11:39:29.141000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       12
# room                                 COMPUTER_LAB
# time_duration                                   0
# Name: 518, dtype: object, time             2019-10-08 12:00:34.788000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       12
# room                                 COMPUTER_LAB
# time_duration                                   0
# Name: 529, dtype: object], [time             2019-10-08 15:17:24.670000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 604, dtype: object, time             2019-10-08 15:42:23.664000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       -1
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 613, dtype: object], [time             2019-10-08 17:56:55.896000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 669, dtype: object, time             2019-10-08 18:23:21.692000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 675, dtype: object], [time             2019-10-08 19:27:12.750000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       -1
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 689, dtype: object, time             2019-10-08 19:44:33.497000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 693, dtype: object, time             2019-10-08 20:13:58.578000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 700, dtype: object], [time             2019-10-09 11:19:54.124000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 826, dtype: object, time             2019-10-09 11:39:14.416000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 832, dtype: object], [time             2019-10-15 10:51:25.118000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1806, dtype: object, time             2019-10-15 11:09:31.834000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1811, dtype: object], [time             2019-10-17 01:22:54.147000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2131, dtype: object, time             2019-10-17 01:49:26.219000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2132, dtype: object], [time             2019-10-17 08:59:14.750000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2135, dtype: object, time             2019-10-17 09:26:38.172000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2139, dtype: object, time             2019-10-17 09:53:02.252000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2144, dtype: object], [time             2019-10-17 22:38:10.719000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 2311, dtype: object, time             2019-10-17 23:04:31.564000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2313, dtype: object]]

# %% [markdown]
# # Keep clusters with more than a certain amount of data points and remove NaN

# %%
# Split the cluster up according to their timing
for i in range(len(all_clusters)):
    if (len(all_clusters[i]) > 1):
        # If have more than 1 datapoint
        tempList = all_clusters[i] # Store into tempList for splitting
        tempList2 = [] # Store all relevant datapoints in a cluster together before pushing into flitered_cluster
        nextDataPoint = []
         # Check if current datapoint is part of the cluster and room is not null
        for j in range(len(tempList)):
            space = tempList[j].Space_id
            
            if(isNaN(space) == False):    
                if (j == 0):
                    tempList2.append(tempList[j])
                    last_time = tempList[j].time

                elif (tempList[j].time < last_time + pd.Timedelta(minutes=30)):
                    tempList2.append(tempList[j])
                    last_time = tempList[j].time

        filtered_cluster_after.append(tempList2)
print(filtered_cluster_after)
# Out:
# [[time             2019-10-07 11:18:13.974000+08:00
# thermal_cozie                                 NaN
# user_id                                   cresh13
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 288, dtype: object, time             2019-10-07 11:24:11.151000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 290, dtype: object, time             2019-10-07 11:40:52.354000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 292, dtype: object], [time             2019-10-07 16:54:23.269000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 391, dtype: object, time             2019-10-07 17:09:20.900000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 402, dtype: object, time             2019-10-07 17:38:04.240000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 414, dtype: object], [time             2019-10-07 19:19:53.105000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 430, dtype: object, time             2019-10-07 19:39:14.816000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 434, dtype: object], [time             2019-10-07 22:43:46.367000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 443, dtype: object], [time             2019-10-08 11:39:29.141000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       12
# room                                 COMPUTER_LAB
# time_duration                                   0
# Name: 518, dtype: object, time             2019-10-08 12:00:34.788000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       12
# room                                 COMPUTER_LAB
# time_duration                                   0
# Name: 529, dtype: object], [time             2019-10-08 15:17:24.670000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 604, dtype: object, time             2019-10-08 15:42:23.664000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       -1
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 613, dtype: object], [time             2019-10-08 17:56:55.896000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 669, dtype: object, time             2019-10-08 18:23:21.692000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 675, dtype: object], [time             2019-10-08 19:27:12.750000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       -1
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 689, dtype: object, time             2019-10-08 19:44:33.497000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 693, dtype: object], [], [], [], [], [time             2019-10-17 22:38:10.719000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 2311, dtype: object]]

# %% [markdown]
# # Show how many datapoints are in each cluster prior to removing

# %%
for i in range(len(filtered_cluster_before)):
    print("{0}:{1} ".format(i,(len(filtered_cluster_before[i]))))
# Out:
# 0:3
# 1:3
# 2:2
# 3:3
# 4:2
# 5:2
# 6:2
# 7:3
# 8:2
# 9:2
# 10:2
# 11:3
# 12:2

# %% [markdown]
# # Add in values to the duration difference column

# %%
for i in range(len(filtered_cluster_before)):
    # First variable have no time difference, thus 0.0s
    timeDifferenceList = [0.0]
    for j in range(len(filtered_cluster_before[i])):
        if (j == 0):
            last_time = filtered_cluster_before[i][j].time
        else:
            timeDiff = filtered_cluster_before[i][j].time - last_time
            filtered_cluster_before[i][j].time_duration = (timeDiff.total_seconds()/60)
            # Set the last time as the current one
            last_time = filtered_cluster_before[i][j].time
            
for i in range(len(filtered_cluster_after)):
    # First variable have no time difference, thus 0.0s
    timeDifferenceList = [0.0]
    for j in range(len(filtered_cluster_after[i])):
        if (j == 0):
            last_time = filtered_cluster_after[i][j].time
        else:
            timeDiff = filtered_cluster_after[i][j].time - last_time
            filtered_cluster_after[i][j].time_duration = (timeDiff.total_seconds()/60)
            # Set the last time as the current one
            last_time = filtered_cluster_after[i][j].time

# %% [markdown]
# # Plot all graph before removal of NaN

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_before)):
    for j in range(len(filtered_cluster_before[i])):
        base += filtered_cluster_before[i][j].time_duration
        thermal.append(filtered_cluster_before[i][j].thermal_cozie)
        duration.append(base)
        
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.ylim(9,11)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot all graph seperately before removal of NaN

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_before)):
    for j in range(len(filtered_cluster_before[i])):
        base += filtered_cluster_before[i][j].time_duration
        thermal.append(filtered_cluster_before[i][j].thermal_cozie)
        duration.append(base)
    
    plt.figure()
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Remove list with zero elements inside filtered_cluster_after

# %%
tempList3 = []
for i in range(len(filtered_cluster_after)):
    if (len(filtered_cluster_after[i]) > 1):
        tempList3.append(filtered_cluster_after[i])

filtered_cluster_after = tempList3
print(filtered_cluster_after)
# Out:
# [[time             2019-10-07 11:18:13.974000+08:00
# thermal_cozie                                 NaN
# user_id                                   cresh13
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 288, dtype: object, time             2019-10-07 11:24:11.151000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             5.95295
# Name: 290, dtype: object, time             2019-10-07 11:40:52.354000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             16.6867
# Name: 292, dtype: object], [time             2019-10-07 16:54:23.269000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 391, dtype: object, time             2019-10-07 17:09:20.900000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                             14.9605
# Name: 402, dtype: object, time             2019-10-07 17:38:04.240000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                             28.7223
# Name: 414, dtype: object], [time             2019-10-07 19:19:53.105000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 430, dtype: object, time             2019-10-07 19:39:14.816000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                             19.3619
# Name: 434, dtype: object], [time             2019-10-08 11:39:29.141000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       12
# room                                 COMPUTER_LAB
# time_duration                                   0
# Name: 518, dtype: object, time             2019-10-08 12:00:34.788000+08:00
# thermal_cozie                                  10
# user_id                                   cresh13
# Space_id                                       12
# room                                 COMPUTER_LAB
# time_duration                             21.0941
# Name: 529, dtype: object], [time             2019-10-08 15:17:24.670000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 604, dtype: object, time             2019-10-08 15:42:23.664000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       -1
# room                            NEAR_DIC_STUDIO_1
# time_duration                             24.9832
# Name: 613, dtype: object], [time             2019-10-08 17:56:55.896000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                                   0
# Name: 669, dtype: object, time             2019-10-08 18:23:21.692000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       10
# room                            NEAR_DIC_STUDIO_1
# time_duration                             26.4299
# Name: 675, dtype: object], [time             2019-10-08 19:27:12.750000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       -1
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 689, dtype: object, time             2019-10-08 19:44:33.497000+08:00
# thermal_cozie                                  11
# user_id                                   cresh13
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                             17.3458
# Name: 693, dtype: object]]

# %% [markdown]
# # Show how many datapoint are in each cluster after filtering NaN and zero element

# %%
for i in range(len(filtered_cluster_after)):
    print("{0}:{1} ".format(i,(len(filtered_cluster_after[i]))))
# Out:
# 0:3
# 1:3
# 2:2
# 3:2
# 4:2
# 5:2
# 6:2

# %% [markdown]
# # Plot all cluster into one graph

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_after)):
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
        
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot all cluster into separate graphs

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_after)):
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
    
    plt.figure()
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot test with vertical dotted lines

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0
dotted_lines = []

for i in range(len(filtered_cluster_after)):
    tempList = []
    for j in range(len(filtered_cluster_after[i])):
        if (j > 1):
            prev = filtered_cluster_after[i][j-1].room
            curr = filtered_cluster_after[i][j].room
            
            if (prev != curr):
                tempList.append(j)
                
    dotted_lines.append(tempList)

#print(dotted_lines)
    
for i in range(len(filtered_cluster_after)):
    lines = []
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
        
    if(len(dotted_lines[i]) > 0):
        while(len(dotted_lines[i]) > 0):
            index = dotted_lines[i].pop()
            xValue = duration[index]
            plt.axvline(x = xValue, linestyle = '--', color = 'r')
        
        
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    plt.show()
    
    #print(filtered_cluster_after[0])
    #print(duration)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []
