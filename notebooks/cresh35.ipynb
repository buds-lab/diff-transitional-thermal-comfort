# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure

# %%
fig = Figure()
canvas = FigureCanvas(fig)
ax = fig.add_subplot(111)

# %%
def isNaN(num):
    return num != num

# %%
df = pd.read_csv ("2019-10-29_cozie_full.csv", index_col=0)
filtered_df = df.drop (columns=['clothing','lat_cozie','lon_cozie','responseSpeed_cozie','Floor','Latitude','Longitude','noise_sensing','voc_sensing','index','comfort_cozie','heartRate_cozie','light_cozie','noise_cozie','co2_sensing','humidity_sensing','light_sensing','temperature_sensing','temperature_mbient'],axis=1)
filtered_df['time'] = filtered_df['time'].apply(pd.Timestamp).dt.tz_convert('Asia/Singapore')
# Add new column to calculate duration 
filtered_df['time_duration'] = 0

# %%
grouped_users = filtered_df.groupby('user_id')

all_clusters = [] # Raw data
cluster_array = [] 
filtered_cluster_before = [] # Raw data that are clustered together according to duration
filtered_cluster_after = []

# %%
cresh01_df = grouped_users.get_group('cresh35')
thermal_cozie_ticks = [9,10,11]

# %%
# Gather all data relevant to specific user 
for index, datapoint in cresh01_df.iterrows():
    # print (data.time)
    if cluster_array == []:
        cluster_array.append(datapoint)
    else:
        if datapoint.time < last_time + pd.Timedelta(minutes=30):
            cluster_array.append(datapoint) 
        else:
            all_clusters.append(cluster_array)
            cluster_array = []
            cluster_array.append(datapoint)

    
    last_time = datapoint.time
#print (all_clusters)

# %% [markdown]
# # Keep clusters with more than a certain amount of data points

# %%
# Split the cluster up according to their timing
for i in range(len(all_clusters)):
    if (len(all_clusters[i]) > 1):
        # If have more than 1 datapoint
        tempList = all_clusters[i] # Store into tempList for splitting
        tempList2 = [] # Store all relevant datapoints in a cluster together before pushing into flitered_cluster
        nextDataPoint = []
         # Check if current datapoint is part of the cluster and room is not null
        for j in range(len(tempList)):
            space = tempList[j].Space_id

            if (j == 0):
                tempList2.append(tempList[j])
                last_time = tempList[j].time

            elif (tempList[j].time < last_time + pd.Timedelta(minutes=30)):
                tempList2.append(tempList[j])
                last_time = tempList[j].time

        filtered_cluster_before.append(tempList2)
print(filtered_cluster_before)
# Out:
# [[time             2019-09-30 12:08:23.750000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 8, dtype: object, time             2019-09-30 12:37:53.719000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 9, dtype: object, time             2019-09-30 12:48:46.900000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 10, dtype: object, time             2019-09-30 12:53:00.125000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                        1
# room                                         CAFE
# time_duration                                   0
# Name: 11, dtype: object, time             2019-09-30 13:02:37.388000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                        1
# room                                         CAFE
# time_duration                                   0
# Name: 12, dtype: object], [time             2019-09-30 18:00:13.137000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 25, dtype: object, time             2019-09-30 18:07:57.632000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 26, dtype: object], [time             2019-10-01 12:14:27+08:00
# thermal_cozie                           10
# user_id                            cresh35
# Space_id                                45
# room                              BUDS_LAB
# time_duration                            0
# Name: 42, dtype: object, time             2019-10-01 12:35:04.545000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 43, dtype: object, time             2019-10-01 12:51:55.576000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 44, dtype: object], [time             2019-10-02 10:04:32.104000+08:00
# thermal_cozie                                 NaN
# user_id                                   cresh35
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 67, dtype: object, time             2019-10-02 10:05:10.840000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 68, dtype: object], [time             2019-10-02 11:14:12.692000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 71, dtype: object, time             2019-10-02 11:19:26.923000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 73, dtype: object], [time             2019-10-02 17:21:50.497000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 89, dtype: object, time             2019-10-02 17:34:13.748000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 91, dtype: object], [time             2019-10-02 19:31:23.776000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 92, dtype: object, time             2019-10-02 19:35:35.388000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 93, dtype: object], [time             2019-10-03 08:59:28.246000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 94, dtype: object, time             2019-10-03 09:05:02.640000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 95, dtype: object], [time             2019-10-03 10:25:27.640000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                        2
# room                                 ENERGY_LAB_1
# time_duration                                   0
# Name: 96, dtype: object, time             2019-10-03 10:42:55.510000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                        2
# room                                 ENERGY_LAB_1
# time_duration                                   0
# Name: 97, dtype: object, time             2019-10-03 11:03:25.931000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                        2
# room                                 ENERGY_LAB_1
# time_duration                                   0
# Name: 99, dtype: object], [time             2019-10-03 17:07:57.744000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 106, dtype: object, time             2019-10-03 17:12:31.148000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 109, dtype: object], [time             2019-10-15 17:10:48.431000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 1908, dtype: object, time             2019-10-15 17:31:42.634000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1922, dtype: object], [time             2019-10-16 15:18:37.492000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2060, dtype: object, time             2019-10-16 15:26:41.959000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2063, dtype: object, time             2019-10-16 15:27:19.760000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2064, dtype: object], [time             2019-10-17 09:07:04.786000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2136, dtype: object, time             2019-10-17 09:24:00.592000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2138, dtype: object], [time             2019-10-18 10:50:52.033000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2346, dtype: object, time             2019-10-18 10:51:30.991000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2347, dtype: object], [time             2019-10-18 13:06:51.384000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2382, dtype: object, time             2019-10-18 13:24:29.560000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                        2
# room                                 ENERGY_LAB_1
# time_duration                                   0
# Name: 2388, dtype: object, time             2019-10-18 13:28:21.546000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2389, dtype: object], [time             2019-10-20 10:17:33.813000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 2516, dtype: object, time             2019-10-20 10:19:47.844000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                        0
# room                                          NaN
# time_duration                                   0
# Name: 2517, dtype: object], [time             2019-10-21 11:09:37.760000+08:00
# thermal_cozie                                 NaN
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2574, dtype: object, time             2019-10-21 11:31:39.763000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2578, dtype: object], [time             2019-10-23 13:52:05.624000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3144, dtype: object, time             2019-10-23 13:57:10.319000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3147, dtype: object], [time             2019-10-24 11:33:04.628000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3376, dtype: object, time             2019-10-24 11:43:56.790000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3379, dtype: object], [time             2019-10-24 14:12:43.748000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3443, dtype: object, time             2019-10-24 14:16:14.799000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3447, dtype: object], [time             2019-10-25 09:34:54.319000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3564, dtype: object, time             2019-10-25 09:45:15.799000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3565, dtype: object]]

# %% [markdown]
# # Keep clusters with more than a certain amount of data points and remove NaN

# %%
# Split the cluster up according to their timing
for i in range(len(all_clusters)):
    if (len(all_clusters[i]) > 1):
        # If have more than 1 datapoint
        tempList = all_clusters[i] # Store into tempList for splitting
        tempList2 = [] # Store all relevant datapoints in a cluster together before pushing into flitered_cluster
        nextDataPoint = []
         # Check if current datapoint is part of the cluster and room is not null
        for j in range(len(tempList)):
            space = tempList[j].Space_id
            
            if(isNaN(space) == False):    
                if (j == 0):
                    tempList2.append(tempList[j])
                    last_time = tempList[j].time

                elif (tempList[j].time < last_time + pd.Timedelta(minutes=30)):
                    tempList2.append(tempList[j])
                    last_time = tempList[j].time

        filtered_cluster_after.append(tempList2)
print(filtered_cluster_after)
# Out:
# [[time             2019-09-30 12:08:23.750000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 8, dtype: object], [time             2019-09-30 18:00:13.137000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 25, dtype: object, time             2019-09-30 18:07:57.632000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 26, dtype: object], [time             2019-10-01 12:14:27+08:00
# thermal_cozie                           10
# user_id                            cresh35
# Space_id                                45
# room                              BUDS_LAB
# time_duration                            0
# Name: 42, dtype: object], [time             2019-10-02 10:04:32.104000+08:00
# thermal_cozie                                 NaN
# user_id                                   cresh35
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 67, dtype: object, time             2019-10-02 10:05:10.840000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 68, dtype: object], [time             2019-10-02 11:14:12.692000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 71, dtype: object, time             2019-10-02 11:19:26.923000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 73, dtype: object], [], [], [], [time             2019-10-03 10:25:27.640000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                        2
# room                                 ENERGY_LAB_1
# time_duration                                   0
# Name: 96, dtype: object, time             2019-10-03 10:42:55.510000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                        2
# room                                 ENERGY_LAB_1
# time_duration                                   0
# Name: 97, dtype: object, time             2019-10-03 11:03:25.931000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                        2
# room                                 ENERGY_LAB_1
# time_duration                                   0
# Name: 99, dtype: object], [], [time             2019-10-15 17:10:48.431000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 1908, dtype: object], [], [], [time             2019-10-18 10:50:52.033000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2346, dtype: object, time             2019-10-18 10:51:30.991000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2347, dtype: object], [], [time             2019-10-20 10:17:33.813000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 2516, dtype: object, time             2019-10-20 10:19:47.844000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                        0
# room                                          NaN
# time_duration                                   0
# Name: 2517, dtype: object], [], [], [], [], []]

# %% [markdown]
# # Show how many datapoints are in each cluster prior to removing

# %%
for i in range(len(filtered_cluster_before)):
    print("{0}:{1} ".format(i,(len(filtered_cluster_before[i]))))
# Out:
# 0:5
# 1:2
# 2:3
# 3:2
# 4:2
# 5:2
# 6:2
# 7:2
# 8:3
# 9:2
# 10:2
# 11:3
# 12:2
# 13:2
# 14:3
# 15:2
# 16:2
# 17:2
# 18:2
# 19:2
# 20:2

# %% [markdown]
# # Add in values to the duration difference column

# %%
for i in range(len(filtered_cluster_before)):
    # First variable have no time difference, thus 0.0s
    timeDifferenceList = [0.0]
    for j in range(len(filtered_cluster_before[i])):
        if (j == 0):
            last_time = filtered_cluster_before[i][j].time
        else:
            timeDiff = filtered_cluster_before[i][j].time - last_time
            filtered_cluster_before[i][j].time_duration = (timeDiff.total_seconds()/60)
            # Set the last time as the current one
            last_time = filtered_cluster_before[i][j].time
            
for i in range(len(filtered_cluster_after)):
    # First variable have no time difference, thus 0.0s
    timeDifferenceList = [0.0]
    for j in range(len(filtered_cluster_after[i])):
        if (j == 0):
            last_time = filtered_cluster_after[i][j].time
        else:
            timeDiff = filtered_cluster_after[i][j].time - last_time
            filtered_cluster_after[i][j].time_duration = (timeDiff.total_seconds()/60)
            # Set the last time as the current one
            last_time = filtered_cluster_after[i][j].time

# %% [markdown]
# # Plot all graph before removal of NaN

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_before)):
    for j in range(len(filtered_cluster_before[i])):
        base += filtered_cluster_before[i][j].time_duration
        thermal.append(filtered_cluster_before[i][j].thermal_cozie)
        duration.append(base)
        
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.ylim(9,11)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot all graph seperately before removal of NaN

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_before)):
    for j in range(len(filtered_cluster_before[i])):
        base += filtered_cluster_before[i][j].time_duration
        thermal.append(filtered_cluster_before[i][j].thermal_cozie)
        duration.append(base)
    
    plt.figure()
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if sys.path[0] == '':

# %% [markdown]
# # Remove list with zero elements inside filtered_cluster_after

# %%
tempList3 = []
for i in range(len(filtered_cluster_after)):
    if (len(filtered_cluster_after[i]) > 1):
        tempList3.append(filtered_cluster_after[i])

filtered_cluster_after = tempList3
print(filtered_cluster_after)
# Out:
# [[time             2019-09-30 18:00:13.137000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 25, dtype: object, time             2019-09-30 18:07:57.632000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             7.74158
# Name: 26, dtype: object], [time             2019-10-02 10:04:32.104000+08:00
# thermal_cozie                                 NaN
# user_id                                   cresh35
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 67, dtype: object, time             2019-10-02 10:05:10.840000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                              0.6456
# Name: 68, dtype: object], [time             2019-10-02 11:14:12.692000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 71, dtype: object, time             2019-10-02 11:19:26.923000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             5.23718
# Name: 73, dtype: object], [time             2019-10-03 10:25:27.640000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                        2
# room                                 ENERGY_LAB_1
# time_duration                                   0
# Name: 96, dtype: object, time             2019-10-03 10:42:55.510000+08:00
# thermal_cozie                                   9
# user_id                                   cresh35
# Space_id                                        2
# room                                 ENERGY_LAB_1
# time_duration                             17.4645
# Name: 97, dtype: object, time             2019-10-03 11:03:25.931000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                        2
# room                                 ENERGY_LAB_1
# time_duration                              20.507
# Name: 99, dtype: object], [time             2019-10-18 10:50:52.033000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2346, dtype: object, time             2019-10-18 10:51:30.991000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                              0.6493
# Name: 2347, dtype: object], [time             2019-10-20 10:17:33.813000+08:00
# thermal_cozie                                  11
# user_id                                   cresh35
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 2516, dtype: object, time             2019-10-20 10:19:47.844000+08:00
# thermal_cozie                                  10
# user_id                                   cresh35
# Space_id                                        0
# room                                          NaN
# time_duration                             2.23385
# Name: 2517, dtype: object]]

# %% [markdown]
# # Show how many datapoint are in each cluster after filtering NaN and zero element

# %%
for i in range(len(filtered_cluster_after)):
    print("{0}:{1} ".format(i,(len(filtered_cluster_after[i]))))
# Out:
# 0:2
# 1:2
# 2:2
# 3:3
# 4:2
# 5:2

# %% [markdown]
# # Plot all cluster into one graph

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_after)):
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
        
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot all cluster into separate graphs

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_after)):
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
    
    plt.figure()
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot test with vertical dotted lines

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0
dotted_lines = []

for i in range(len(filtered_cluster_after)):
    tempList = []
    for j in range(len(filtered_cluster_after[i])):
        if (j > 1):
            prev = filtered_cluster_after[i][j-1].room
            curr = filtered_cluster_after[i][j].room
            
            if (prev != curr):
                tempList.append(j)
                
    dotted_lines.append(tempList)

#print(dotted_lines)
    
for i in range(len(filtered_cluster_after)):
    lines = []
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
        
    if(len(dotted_lines[i]) > 0):
        while(len(dotted_lines[i]) > 0):
            index = dotted_lines[i].pop()
            xValue = duration[index]
            plt.axvline(x = xValue, linestyle = '--', color = 'r')
        
        
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    plt.show()
    
    #print(filtered_cluster_after[0])
    #print(duration)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []
