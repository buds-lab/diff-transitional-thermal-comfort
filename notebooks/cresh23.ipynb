# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure

# %%
fig = Figure()
canvas = FigureCanvas(fig)
ax = fig.add_subplot(111)

# %%
def isNaN(num):
    return num != num

# %%
df = pd.read_csv ("2019-10-29_cozie_full.csv", index_col=0)
filtered_df = df.drop (columns=['clothing','lat_cozie','lon_cozie','responseSpeed_cozie','Floor','Latitude','Longitude','noise_sensing','voc_sensing','index','comfort_cozie','heartRate_cozie','light_cozie','noise_cozie','co2_sensing','humidity_sensing','light_sensing','temperature_sensing','temperature_mbient'],axis=1)
filtered_df['time'] = filtered_df['time'].apply(pd.Timestamp).dt.tz_convert('Asia/Singapore')
# Add new column to calculate duration 
filtered_df['time_duration'] = 0

# %%
grouped_users = filtered_df.groupby('user_id')

all_clusters = [] # Raw data
cluster_array = [] 
filtered_cluster_before = [] # Raw data that are clustered together according to duration
filtered_cluster_after = []

# %%
cresh01_df = grouped_users.get_group('cresh23')
thermal_cozie_ticks = [9,10,11]

# %%
# Gather all data relevant to specific user 
for index, datapoint in cresh01_df.iterrows():
    # print (data.time)
    if cluster_array == []:
        cluster_array.append(datapoint)
    else:
        if datapoint.time < last_time + pd.Timedelta(minutes=30):
            cluster_array.append(datapoint) 
        else:
            all_clusters.append(cluster_array)
            cluster_array = []
            cluster_array.append(datapoint)

    
    last_time = datapoint.time
#print (all_clusters)

# %% [markdown]
# # Keep clusters with more than a certain amount of data points

# %%
# Split the cluster up according to their timing
for i in range(len(all_clusters)):
    if (len(all_clusters[i]) > 1):
        # If have more than 1 datapoint
        tempList = all_clusters[i] # Store into tempList for splitting
        tempList2 = [] # Store all relevant datapoints in a cluster together before pushing into flitered_cluster
        nextDataPoint = []
         # Check if current datapoint is part of the cluster and room is not null
        for j in range(len(tempList)):
            space = tempList[j].Space_id

            if (j == 0):
                tempList2.append(tempList[j])
                last_time = tempList[j].time

            elif (tempList[j].time < last_time + pd.Timedelta(minutes=30)):
                tempList2.append(tempList[j])
                last_time = tempList[j].time

        filtered_cluster_before.append(tempList2)
print(filtered_cluster_before)
# Out:
# [[time             2019-10-21 10:32:42.740000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2562, dtype: object, time             2019-10-21 10:52:53.114000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2567, dtype: object, time             2019-10-21 11:10:13.984000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2575, dtype: object, time             2019-10-21 11:33:51.269000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 2579, dtype: object, time             2019-10-21 11:59:45.578000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 2587, dtype: object, time             2019-10-21 12:17:01.723000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                        1
# room                                         CAFE
# time_duration                                   0
# Name: 2593, dtype: object, time             2019-10-21 12:31:12.753000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 2599, dtype: object, time             2019-10-21 12:51:05.160000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 2608, dtype: object], [time             2019-10-21 14:30:20.553000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 2651, dtype: object, time             2019-10-21 14:53:28.260000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2660, dtype: object, time             2019-10-21 15:12:20.828000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2670, dtype: object, time             2019-10-21 15:31:41.380000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2685, dtype: object, time             2019-10-21 15:40:36.768000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2687, dtype: object, time             2019-10-21 16:03:06.361000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2698, dtype: object, time             2019-10-21 16:19:48.968000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2706, dtype: object, time             2019-10-21 16:36:37.292000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2711, dtype: object, time             2019-10-21 16:56:01.200000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2723, dtype: object, time             2019-10-21 17:15:16.647000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2733, dtype: object, time             2019-10-21 17:31:39.229000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2739, dtype: object, time             2019-10-21 18:00:36.674000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2752, dtype: object, time             2019-10-21 18:20:21.920000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2761, dtype: object], [time             2019-10-21 19:15:12.824000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2779, dtype: object, time             2019-10-21 19:36:23.147000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2782, dtype: object], [time             2019-10-22 09:44:19.395000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2829, dtype: object, time             2019-10-22 10:01:31.378000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2830, dtype: object, time             2019-10-22 10:25:17.299000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2834, dtype: object], [time             2019-10-22 10:56:40.846000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2843, dtype: object, time             2019-10-22 11:26:24.736000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2854, dtype: object], [time             2019-10-22 12:46:42.207000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2870, dtype: object, time             2019-10-22 13:11:47.790000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2878, dtype: object], [time             2019-10-22 13:55:14.872000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2886, dtype: object, time             2019-10-22 14:17:17.451000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2894, dtype: object], [time             2019-10-22 16:51:06.392000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2936, dtype: object, time             2019-10-22 17:11:38.740000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2948, dtype: object, time             2019-10-22 17:32:05.275000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2957, dtype: object, time             2019-10-22 17:52:46.563000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                                          NaN
# time_duration                                   0
# Name: 2963, dtype: object, time             2019-10-22 18:16:57.180000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                                   0
# Name: 2972, dtype: object, time             2019-10-22 18:46:33.150000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                                   0
# Name: 2980, dtype: object], [time             2019-10-22 19:30:24.862000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                                   0
# Name: 2991, dtype: object, time             2019-10-22 19:48:36.780000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                                   0
# Name: 2999, dtype: object], [time             2019-10-23 08:40:51.100000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3050, dtype: object, time             2019-10-23 08:59:00.616000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3052, dtype: object, time             2019-10-23 09:20:06.852000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3055, dtype: object], [time             2019-10-23 10:06:18.456000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3062, dtype: object, time             2019-10-23 10:33:01.444000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3068, dtype: object, time             2019-10-23 10:50:40.473000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3077, dtype: object], [time             2019-10-23 13:09:12.816000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3123, dtype: object, time             2019-10-23 13:29:30.950000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3135, dtype: object, time             2019-10-23 13:50:38.586000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3143, dtype: object], [time             2019-10-23 15:50:00.469000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3189, dtype: object, time             2019-10-23 16:16:22.552000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3199, dtype: object], [time             2019-10-23 17:06:18.329000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3222, dtype: object, time             2019-10-23 17:20:17.160000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3234, dtype: object, time             2019-10-23 17:36:38.928000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3241, dtype: object], [time             2019-10-24 09:01:24.048000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3336, dtype: object, time             2019-10-24 09:28:32.778000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3344, dtype: object], [time             2019-10-25 17:15:45.395000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3660, dtype: object, time             2019-10-25 17:35:20.170000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3663, dtype: object, time             2019-10-25 18:03:16.599000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3669, dtype: object], [time             2019-10-27 17:50:42.664000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3737, dtype: object, time             2019-10-27 18:09:00.298000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3738, dtype: object, time             2019-10-27 18:26:07.509000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 3739, dtype: object]]

# %% [markdown]
# # Keep clusters with more than a certain amount of data points and remove NaN

# %%
# Split the cluster up according to their timing
for i in range(len(all_clusters)):
    if (len(all_clusters[i]) > 1):
        # If have more than 1 datapoint
        tempList = all_clusters[i] # Store into tempList for splitting
        tempList2 = [] # Store all relevant datapoints in a cluster together before pushing into flitered_cluster
        nextDataPoint = []
         # Check if current datapoint is part of the cluster and room is not null
        for j in range(len(tempList)):
            space = tempList[j].Space_id
            
            if(isNaN(space) == False):    
                if (j == 0):
                    tempList2.append(tempList[j])
                    last_time = tempList[j].time

                elif (tempList[j].time < last_time + pd.Timedelta(minutes=30)):
                    tempList2.append(tempList[j])
                    last_time = tempList[j].time

        filtered_cluster_after.append(tempList2)
print(filtered_cluster_after)
# Out:
# [[time             2019-10-21 10:32:42.740000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2562, dtype: object, time             2019-10-21 10:52:53.114000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2567, dtype: object, time             2019-10-21 11:10:13.984000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2575, dtype: object, time             2019-10-21 11:33:51.269000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 2579, dtype: object, time             2019-10-21 11:59:45.578000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 2587, dtype: object, time             2019-10-21 12:17:01.723000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                        1
# room                                         CAFE
# time_duration                                   0
# Name: 2593, dtype: object, time             2019-10-21 12:31:12.753000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 2599, dtype: object, time             2019-10-21 12:51:05.160000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 2608, dtype: object], [time             2019-10-21 14:30:20.553000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 2651, dtype: object, time             2019-10-21 14:53:28.260000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2660, dtype: object, time             2019-10-21 15:12:20.828000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2670, dtype: object, time             2019-10-21 15:31:41.380000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2685, dtype: object, time             2019-10-21 15:40:36.768000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2687, dtype: object, time             2019-10-21 16:03:06.361000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2698, dtype: object, time             2019-10-21 16:19:48.968000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2706, dtype: object, time             2019-10-21 16:36:37.292000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2711, dtype: object], [], [], [time             2019-10-22 10:56:40.846000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2843, dtype: object, time             2019-10-22 11:26:24.736000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2854, dtype: object], [time             2019-10-22 12:46:42.207000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2870, dtype: object], [], [time             2019-10-22 16:51:06.392000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2936, dtype: object, time             2019-10-22 17:11:38.740000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2948, dtype: object, time             2019-10-22 17:32:05.275000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2957, dtype: object, time             2019-10-22 17:52:46.563000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                                          NaN
# time_duration                                   0
# Name: 2963, dtype: object, time             2019-10-22 18:16:57.180000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                                   0
# Name: 2972, dtype: object, time             2019-10-22 18:46:33.150000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                                   0
# Name: 2980, dtype: object], [time             2019-10-22 19:30:24.862000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                                   0
# Name: 2991, dtype: object, time             2019-10-22 19:48:36.780000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                                   0
# Name: 2999, dtype: object], [], [time             2019-10-23 10:06:18.456000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3062, dtype: object, time             2019-10-23 10:33:01.444000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3068, dtype: object], [time             2019-10-23 13:09:12.816000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3123, dtype: object, time             2019-10-23 13:29:30.950000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3135, dtype: object, time             2019-10-23 13:50:38.586000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3143, dtype: object], [time             2019-10-23 15:50:00.469000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3189, dtype: object, time             2019-10-23 16:16:22.552000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3199, dtype: object], [time             2019-10-23 17:06:18.329000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3222, dtype: object, time             2019-10-23 17:20:17.160000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3234, dtype: object], [], [], []]

# %% [markdown]
# # Show how many datapoints are in each cluster prior to removing

# %%
for i in range(len(filtered_cluster_before)):
    print("{0}:{1} ".format(i,(len(filtered_cluster_before[i]))))
# Out:
# 0:8
# 1:13
# 2:2
# 3:3
# 4:2
# 5:2
# 6:2
# 7:6
# 8:2
# 9:3
# 10:3
# 11:3
# 12:2
# 13:3
# 14:2
# 15:3
# 16:3

# %% [markdown]
# # Add in values to the duration difference column

# %%
for i in range(len(filtered_cluster_before)):
    # First variable have no time difference, thus 0.0s
    timeDifferenceList = [0.0]
    for j in range(len(filtered_cluster_before[i])):
        if (j == 0):
            last_time = filtered_cluster_before[i][j].time
        else:
            timeDiff = filtered_cluster_before[i][j].time - last_time
            filtered_cluster_before[i][j].time_duration = (timeDiff.total_seconds()/60)
            # Set the last time as the current one
            last_time = filtered_cluster_before[i][j].time
            
for i in range(len(filtered_cluster_after)):
    # First variable have no time difference, thus 0.0s
    timeDifferenceList = [0.0]
    for j in range(len(filtered_cluster_after[i])):
        if (j == 0):
            last_time = filtered_cluster_after[i][j].time
        else:
            timeDiff = filtered_cluster_after[i][j].time - last_time
            filtered_cluster_after[i][j].time_duration = (timeDiff.total_seconds()/60)
            # Set the last time as the current one
            last_time = filtered_cluster_after[i][j].time

# %% [markdown]
# # Plot all graph before removal of NaN

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_before)):
    for j in range(len(filtered_cluster_before[i])):
        base += filtered_cluster_before[i][j].time_duration
        thermal.append(filtered_cluster_before[i][j].thermal_cozie)
        duration.append(base)
        
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.ylim(9,11)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot all graph seperately before removal of NaN

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_before)):
    for j in range(len(filtered_cluster_before[i])):
        base += filtered_cluster_before[i][j].time_duration
        thermal.append(filtered_cluster_before[i][j].thermal_cozie)
        duration.append(base)
    
    plt.figure()
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Remove list with zero elements inside filtered_cluster_after

# %%
tempList3 = []
for i in range(len(filtered_cluster_after)):
    if (len(filtered_cluster_after[i]) > 1):
        tempList3.append(filtered_cluster_after[i])

filtered_cluster_after = tempList3
print(filtered_cluster_after)
# Out:
# [[time             2019-10-21 10:32:42.740000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2562, dtype: object, time             2019-10-21 10:52:53.114000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             20.1729
# Name: 2567, dtype: object, time             2019-10-21 11:10:13.984000+08:00
# thermal_cozie                                  11
# user_id                                   cresh23
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             17.3478
# Name: 2575, dtype: object, time             2019-10-21 11:33:51.269000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                             23.6214
# Name: 2579, dtype: object, time             2019-10-21 11:59:45.578000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                             25.9051
# Name: 2587, dtype: object, time             2019-10-21 12:17:01.723000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                        1
# room                                         CAFE
# time_duration                             17.2691
# Name: 2593, dtype: object, time             2019-10-21 12:31:12.753000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                             14.1838
# Name: 2599, dtype: object, time             2019-10-21 12:51:05.160000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                             19.8734
# Name: 2608, dtype: object], [time             2019-10-21 14:30:20.553000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       -1
# room                                     CORRIDOR
# time_duration                                   0
# Name: 2651, dtype: object, time             2019-10-21 14:53:28.260000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             23.1285
# Name: 2660, dtype: object, time             2019-10-21 15:12:20.828000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             18.8761
# Name: 2670, dtype: object, time             2019-10-21 15:31:41.380000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             19.3425
# Name: 2685, dtype: object, time             2019-10-21 15:40:36.768000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             8.92313
# Name: 2687, dtype: object, time             2019-10-21 16:03:06.361000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             22.4932
# Name: 2698, dtype: object, time             2019-10-21 16:19:48.968000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             16.7101
# Name: 2706, dtype: object, time             2019-10-21 16:36:37.292000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             16.8054
# Name: 2711, dtype: object], [time             2019-10-22 10:56:40.846000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2843, dtype: object, time             2019-10-22 11:26:24.736000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             29.7315
# Name: 2854, dtype: object], [time             2019-10-22 16:51:06.392000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 2936, dtype: object, time             2019-10-22 17:11:38.740000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             20.5391
# Name: 2948, dtype: object, time             2019-10-22 17:32:05.275000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             20.4423
# Name: 2957, dtype: object, time             2019-10-22 17:52:46.563000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                                          NaN
# time_duration                             20.6881
# Name: 2963, dtype: object, time             2019-10-22 18:16:57.180000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                             24.1769
# Name: 2972, dtype: object, time             2019-10-22 18:46:33.150000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                             29.5995
# Name: 2980, dtype: object], [time             2019-10-22 19:30:24.862000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                                   0
# Name: 2991, dtype: object, time             2019-10-22 19:48:36.780000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       43
# room                     EXECUTIVE_SEMINAR_ROOM_B
# time_duration                             18.1986
# Name: 2999, dtype: object], [time             2019-10-23 10:06:18.456000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3062, dtype: object, time             2019-10-23 10:33:01.444000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             26.7165
# Name: 3068, dtype: object], [time             2019-10-23 13:09:12.816000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3123, dtype: object, time             2019-10-23 13:29:30.950000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             20.3022
# Name: 3135, dtype: object, time             2019-10-23 13:50:38.586000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             21.1273
# Name: 3143, dtype: object], [time             2019-10-23 15:50:00.469000+08:00
# thermal_cozie                                   9
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3189, dtype: object, time             2019-10-23 16:16:22.552000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             26.3681
# Name: 3199, dtype: object], [time             2019-10-23 17:06:18.329000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                                   0
# Name: 3222, dtype: object, time             2019-10-23 17:20:17.160000+08:00
# thermal_cozie                                  10
# user_id                                   cresh23
# Space_id                                       42
# room                     EXECUTIVE_SEMINAR_ROOM_A
# time_duration                             13.9805
# Name: 3234, dtype: object]]

# %% [markdown]
# # Show how many datapoint are in each cluster after filtering NaN and zero element

# %%
for i in range(len(filtered_cluster_after)):
    print("{0}:{1} ".format(i,(len(filtered_cluster_after[i]))))
# Out:
# 0:8
# 1:8
# 2:2
# 3:6
# 4:2
# 5:2
# 6:3
# 7:2
# 8:2

# %% [markdown]
# # Plot all cluster into one graph

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_after)):
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
        
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot all cluster into separate graphs

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_after)):
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
    
    plt.figure()
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot test with vertical dotted lines

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0
dotted_lines = []

for i in range(len(filtered_cluster_after)):
    tempList = []
    for j in range(len(filtered_cluster_after[i])):
        if (j > 1):
            prev = filtered_cluster_after[i][j-1].room
            curr = filtered_cluster_after[i][j].room
            
            if (prev != curr):
                tempList.append(j)
                
    dotted_lines.append(tempList)

#print(dotted_lines)
    
for i in range(len(filtered_cluster_after)):
    lines = []
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
        
    if(len(dotted_lines[i]) > 0):
        while(len(dotted_lines[i]) > 0):
            index = dotted_lines[i].pop()
            xValue = duration[index]
            plt.axvline(x = xValue, linestyle = '--', color = 'r')
        
        
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    plt.show()
    
    #print(filtered_cluster_after[0])
    #print(duration)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []
