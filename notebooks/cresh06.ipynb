# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure

# %%
fig = Figure()
canvas = FigureCanvas(fig)
ax = fig.add_subplot(111)

# %%
def isNaN(num):
    return num != num

# %%
df = pd.read_csv ("2019-10-29_cozie_full.csv", index_col=0)
filtered_df = df.drop (columns=['clothing','lat_cozie','lon_cozie','responseSpeed_cozie','Floor','Latitude','Longitude','noise_sensing','voc_sensing','index','comfort_cozie','heartRate_cozie','light_cozie','noise_cozie','co2_sensing','humidity_sensing','light_sensing','temperature_sensing','temperature_mbient'],axis=1)
filtered_df['time'] = filtered_df['time'].apply(pd.Timestamp).dt.tz_convert('Asia/Singapore')
# Add new column to calculate duration 
filtered_df['time_duration'] = 0

# %%
grouped_users = filtered_df.groupby('user_id')

all_clusters = [] # Raw data
cluster_array = [] 
filtered_cluster_before = [] # Raw data that are clustered together according to duration
filtered_cluster_after = []

# %%
cresh01_df = grouped_users.get_group('cresh06')
thermal_cozie_ticks = [9,10,11]

# %%
# Gather all data relevant to specific user 
for index, datapoint in cresh01_df.iterrows():
    # print (data.time)
    if cluster_array == []:
        cluster_array.append(datapoint)
    else:
        if datapoint.time < last_time + pd.Timedelta(minutes=30):
            cluster_array.append(datapoint) 
        else:
            all_clusters.append(cluster_array)
            cluster_array = []
            cluster_array.append(datapoint)

    
    last_time = datapoint.time
#print (all_clusters)

# %% [markdown]
# # Keep clusters with more than a certain amount of data points

# %%
# Split the cluster up according to their timing
for i in range(len(all_clusters)):
    if (len(all_clusters[i]) > 1):
        # If have more than 1 datapoint
        tempList = all_clusters[i] # Store into tempList for splitting
        tempList2 = [] # Store all relevant datapoints in a cluster together before pushing into flitered_cluster
        nextDataPoint = []
         # Check if current datapoint is part of the cluster and room is not null
        for j in range(len(tempList)):
            space = tempList[j].Space_id

            if (j == 0):
                tempList2.append(tempList[j])
                last_time = tempList[j].time

            elif (tempList[j].time < last_time + pd.Timedelta(minutes=30)):
                tempList2.append(tempList[j])
                last_time = tempList[j].time

        filtered_cluster_before.append(tempList2)
print(filtered_cluster_before)
# Out:
# [[time             2019-10-07 08:56:49.881000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 252, dtype: object, time             2019-10-07 09:11:39.549000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 257, dtype: object, time             2019-10-07 09:19:05.377000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 260, dtype: object, time             2019-10-07 09:31:50.164000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 264, dtype: object, time             2019-10-07 09:49:41.111000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 269, dtype: object, time             2019-10-07 09:56:51.904000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 272, dtype: object, time             2019-10-07 09:57:05.007000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 273, dtype: object, time             2019-10-07 10:16:59.729000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 275, dtype: object, time             2019-10-07 10:31:30.809000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 276, dtype: object, time             2019-10-07 10:46:33.764000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 278, dtype: object, time             2019-10-07 11:00:49.135000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 282, dtype: object, time             2019-10-07 11:02:25.672000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 283, dtype: object, time             2019-10-07 11:15:38.756000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 287, dtype: object, time             2019-10-07 11:31:24.397000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 291, dtype: object, time             2019-10-07 11:46:33.116000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 295, dtype: object, time             2019-10-07 12:02:37.210000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 297, dtype: object, time             2019-10-07 12:13:31.140000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 298, dtype: object, time             2019-10-07 12:27:18.707000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 302, dtype: object, time             2019-10-07 12:30:29.638000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 303, dtype: object, time             2019-10-07 12:45:05.671000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 305, dtype: object, time             2019-10-07 12:59:50.953000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 306, dtype: object, time             2019-10-07 13:01:55.903000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name:
+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 994, dtype: object, time             2019-10-09 17:45:26.421000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 998, dtype: object, time             2019-10-09 17:58:50.188000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1007, dtype: object], [time             2019-10-10 10:56:43.289000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1071, dtype: object, time             2019-10-10 11:01:01.486000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1073, dtype: object], [time             2019-10-10 13:17:38.640000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1107, dtype: object, time             2019-10-10 13:45:49.736000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1115, dtype: object, time             2019-10-10 14:01:14.953000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1122, dtype: object, time             2019-10-10 14:16:11.170000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1128, dtype: object, time             2019-10-10 14:31:12.148000+08:00
# ...
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 1812, dtype: object, time             2019-10-15 11:31:47.303000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1814, dtype: object, time             2019-10-15 11:46:39.601000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1816, dtype: object, time             2019-10-15 12:01:39.492000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1822, dtype: object, time             2019-10-15 12:16:40.802000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1824, dtype: object, time             2019-10-15 12:31:43.727000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 1828, dtype: object, time             2019-10-15 12:46:41+08:00
# thermal_cozie                            9
# user_id                            cresh06
# Space_id                                45
# room                              BUDS_LAB
# time_duration                            0
# Name: 1834, dtype: object, time             2019-10-15 13:01:40.476000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1838, dtype: object], [time             2019-10-15 13:31:41.375000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1845, dtype: object, time             2019-10-15 13:46:41.700000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                                          NaN
# time_duration                                   0
# Name: 1849, dtype: object, time             2019-10-15 14:01:48.480000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1854, dtype: object, time             2019-10-15 14:16:43.354000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1856, dtype: object, time             2019-10-15 14:31:41.780000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1860, dtype: object, time             2019-10-15 14:46:42.953000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1864, dtype: object, time             2019-10-15 15:01:42.755000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1869, dtype: object, time             2019-10-15 15:16:43.435000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1876, dtype: object, time             2019-10-15 15:32:39.872000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 1880, dtype: object], [time             2019-10-16 11:58:59.331000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 1980, dtype: object, time             2019-10-16 11:59:06.140000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 1981, dtype: object], [time             2019-10-16 12:43:37.822000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       -1
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 1992, dtype: object, time             2019-10-16 12:59:22.808000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1997, dtype: object, time             2019-10-16 13:14:16.896000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2007, dtype: object, time             2019-10-16 13:33:43.181000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2012, dtype: object, time             2019-10-16 13:45:32.533000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2019, dtype: object, time             2019-10-16 14:00:07.624000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2025, dtype: object], [time             2019-10-16 14:30:18.480000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2036, dtype: object, time             2019-10-16 14:45:07.884000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2041, dtype: object, time             2019-10-16 15:00:12.396000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2049, dtype: object, time             2019-10-16 15:15:04.348000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2057, dtype: object, time             2019-10-16 15:30:04.566000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2066, dtype: object], [time             2019-10-17 09:45:21.839000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                      NaN
# room                                          NaN
# time_duration                                   0
# Name: 2140, dtype: object, time             2019-10-17 09:48:04.742000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2141, dtype: object, time             2019-10-17 09:48:11.038000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2142, dtype: object, time             2019-10-17 10:16:44.684000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2147, dtype: object, time             2019-10-17 10:30:39.154000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2148, dtype: object, time             2019-10-17 10:48:26.632000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2154, dtype: object, time             2019-10-17 11:15:06.746000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2162, dtype: object, time             2019-10-17 11:38:38.756000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2166, dtype: object, time             2019-10-17 12:01:13.714000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2170, dtype: object], [time             2019-10-17 14:36:16.740000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                        0
# room                                          NaN
# time_duration                                   0
# Name: 2217, dtype: object, time             2019-10-17 14:52:33.805000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2219, dtype: object, time             2019-10-17 15:07:39.118000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2223, dtype: object, time             2019-10-17 15:33:47.468000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2231, dtype: object, time             2019-10-17 15:46:10.944000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2234, dtype: object, time             2019-10-17 16:00:53.452000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2236, dtype: object, time             2019-10-17 16:20:46.269000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2241, dtype: object, time             2019-10-17 16:29:47.552000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2244, dtype: object, time             2019-10-17 16:45:07.321000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2247, dtype: object, time             2019-10-17 17:07:44.151000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2255, dtype: object]]

# %% [markdown]
# # Keep clusters with more than a certain amount of data points and remove NaN

# %%
# Split the cluster up according to their timing
for i in range(len(all_clusters)):
    if (len(all_clusters[i]) > 1):
        # If have more than 1 datapoint
        tempList = all_clusters[i] # Store into tempList for splitting
        tempList2 = [] # Store all relevant datapoints in a cluster together before pushing into flitered_cluster
        nextDataPoint = []
         # Check if current datapoint is part of the cluster and room is not null
        for j in range(len(tempList)):
            space = tempList[j].Space_id
            
            if(isNaN(space) == False):    
                if (j == 0):
                    tempList2.append(tempList[j])
                    last_time = tempList[j].time

                elif (tempList[j].time < last_time + pd.Timedelta(minutes=30)):
                    tempList2.append(tempList[j])
                    last_time = tempList[j].time

        filtered_cluster_after.append(tempList2)
print(filtered_cluster_after)
# Out:
# [[time             2019-10-07 08:56:49.881000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 252, dtype: object, time             2019-10-07 09:19:05.377000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 260, dtype: object, time             2019-10-07 09:31:50.164000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 264, dtype: object], [], [], [], [], [], [], [], [], [time             2019-10-10 15:16:28.805000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1149, dtype: object, time             2019-10-10 15:31:13.118000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1154, dtype: object, time             2019-10-10 15:46:13.345000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1159, dtype: object, time             2019-10-10 16:01:24.525000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1167, dtype: object, time             2019-10-10 16:16:13.039000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1172, dtype: object, time             2019-10-10 16:16:23.128000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1173, dtype: object, time             2019-10-10 16:31:13.137000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1181, dtype: object, time             2019-10-10 16:53:24.694000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 1190, dtype: object, time             2019-10-10 17:03:28.231000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       -1
# room                                IRC_LIBRARY_1
# time_duration                                   0
# Name: 1194, dtype: object], [time             2019-10-11 09:46:23.280000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1304, dtype: object, time             2019-10-11 10:00:48.578000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1307, dtype: object, time             2019-10-11 10:15:35.884000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1311, dtype: object, time             2019-10-11 10:30:41.953000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1314, dtype: object, time             2019-10-11 10:45:32.640000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                                   0
# Name: 1318, dtype: object, time             2019-10-11 11:00:33.165000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1323, dtype: object, time             2019-10-11 11:15:43.209000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1331, dtype: object], [], [], [], [], [time             2019-10-14 16:52:04.783000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1769, dtype: object], [], [time             2019-10-15 13:31:41.375000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1845, dtype: object, time             2019-10-15 13:46:41.700000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                                          NaN
# time_duration                                   0
# Name: 1849, dtype: object, time             2019-10-15 14:01:48.480000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1854, dtype: object, time             2019-10-15 14:16:43.354000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1856, dtype: object], [time             2019-10-16 11:58:59.331000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 1980, dtype: object, time             2019-10-16 11:59:06.140000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 1981, dtype: object], [time             2019-10-16 12:43:37.822000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       -1
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 1992, dtype: object, time             2019-10-16 12:59:22.808000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1997, dtype: object, time             2019-10-16 13:14:16.896000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2007, dtype: object, time             2019-10-16 13:33:43.181000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2012, dtype: object, time             2019-10-16 13:45:32.533000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2019, dtype: object, time             2019-10-16 14:00:07.624000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2025, dtype: object], [time             2019-10-16 14:30:18.480000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2036, dtype: object, time             2019-10-16 14:45:07.884000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2041, dtype: object, time             2019-10-16 15:00:12.396000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2049, dtype: object, time             2019-10-16 15:15:04.348000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2057, dtype: object, time             2019-10-16 15:30:04.566000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2066, dtype: object], [], [time             2019-10-17 14:36:16.740000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                        0
# room                                          NaN
# time_duration                                   0
# Name: 2217, dtype: object, time             2019-10-17 14:52:33.805000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2219, dtype: object, time             2019-10-17 15:07:39.118000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2223, dtype: object, time             2019-10-17 15:33:47.468000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2231, dtype: object, time             2019-10-17 15:46:10.944000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2234, dtype: object, time             2019-10-17 16:00:53.452000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2236, dtype: object, time             2019-10-17 16:20:46.269000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2241, dtype: object, time             2019-10-17 16:29:47.552000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2244, dtype: object, time             2019-10-17 16:45:07.321000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2247, dtype: object, time             2019-10-17 17:07:44.151000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2255, dtype: object]]

# %% [markdown]
# # Show how many datapoints are in each cluster prior to removing

# %%
for i in range(len(filtered_cluster_before)):
    print("{0}:{1} ".format(i,(len(filtered_cluster_before[i]))))
# Out:
# 0:22
# 1:2
# 2:19
# 3:2
# 4:42
# 5:8
# 6:46
# 7:2
# 8:6
# 9:9
# 10:10
# 11:4
# 12:2
# 13:2
# 14:5
# 15:5
# 16:12
# 17:9
# 18:2
# 19:6
# 20:5
# 21:9
# 22:10

# %% [markdown]
# # Add in values to the duration difference column

# %%
for i in range(len(filtered_cluster_before)):
    # First variable have no time difference, thus 0.0s
    timeDifferenceList = [0.0]
    for j in range(len(filtered_cluster_before[i])):
        if (j == 0):
            last_time = filtered_cluster_before[i][j].time
        else:
            timeDiff = filtered_cluster_before[i][j].time - last_time
            filtered_cluster_before[i][j].time_duration = (timeDiff.total_seconds()/60)
            # Set the last time as the current one
            last_time = filtered_cluster_before[i][j].time
            
for i in range(len(filtered_cluster_after)):
    # First variable have no time difference, thus 0.0s
    timeDifferenceList = [0.0]
    for j in range(len(filtered_cluster_after[i])):
        if (j == 0):
            last_time = filtered_cluster_after[i][j].time
        else:
            timeDiff = filtered_cluster_after[i][j].time - last_time
            filtered_cluster_after[i][j].time_duration = (timeDiff.total_seconds()/60)
            # Set the last time as the current one
            last_time = filtered_cluster_after[i][j].time

# %% [markdown]
# # Plot all graph before removal of NaN

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_before)):
    for j in range(len(filtered_cluster_before[i])):
        base += filtered_cluster_before[i][j].time_duration
        thermal.append(filtered_cluster_before[i][j].thermal_cozie)
        duration.append(base)
        
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.ylim(9,11)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot all graph seperately before removal of NaN

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_before)):
    for j in range(len(filtered_cluster_before[i])):
        base += filtered_cluster_before[i][j].time_duration
        thermal.append(filtered_cluster_before[i][j].thermal_cozie)
        duration.append(base)
    
    plt.figure()
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if sys.path[0] == '':

# %% [markdown]
# # Remove list with zero elements inside filtered_cluster_after

# %%
tempList3 = []
for i in range(len(filtered_cluster_after)):
    if (len(filtered_cluster_after[i]) > 1):
        tempList3.append(filtered_cluster_after[i])

filtered_cluster_after = tempList3
print(filtered_cluster_after)
# Out:
# [[time             2019-10-07 08:56:49.881000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 252, dtype: object, time             2019-10-07 09:19:05.377000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             22.2583
# Name: 260, dtype: object, time             2019-10-07 09:31:50.164000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             12.7465
# Name: 264, dtype: object], [time             2019-10-10 15:16:28.805000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1149, dtype: object, time             2019-10-10 15:31:13.118000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             14.7386
# Name: 1154, dtype: object, time             2019-10-10 15:46:13.345000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             15.0038
# Name: 1159, dtype: object, time             2019-10-10 16:01:24.525000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             15.1863
# Name: 1167, dtype: object, time             2019-10-10 16:16:13.039000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             14.8086
# Name: 1172, dtype: object, time             2019-10-10 16:16:23.128000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             0.16815
# Name: 1173, dtype: object, time             2019-10-10 16:31:13.137000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             14.8335
# Name: 1181, dtype: object, time             2019-10-10 16:53:24.694000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                             22.1926
# Name: 1190, dtype: object, time             2019-10-10 17:03:28.231000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       -1
# room                                IRC_LIBRARY_1
# time_duration                              10.059
# Name: 1194, dtype: object], [time             2019-10-11 09:46:23.280000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1304, dtype: object, time             2019-10-11 10:00:48.578000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             14.4216
# Name: 1307, dtype: object, time             2019-10-11 10:15:35.884000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             14.7884
# Name: 1311, dtype: object, time             2019-10-11 10:30:41.953000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             15.1011
# Name: 1314, dtype: object, time             2019-10-11 10:45:32.640000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                                     BUDS_LAB
# time_duration                             14.8448
# Name: 1318, dtype: object, time             2019-10-11 11:00:33.165000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             15.0087
# Name: 1323, dtype: object, time             2019-10-11 11:15:43.209000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             15.1674
# Name: 1331, dtype: object], [time             2019-10-15 13:31:41.375000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 1845, dtype: object, time             2019-10-15 13:46:41.700000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                                          NaN
# time_duration                             15.0054
# Name: 1849, dtype: object, time             2019-10-15 14:01:48.480000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                              15.113
# Name: 1854, dtype: object, time             2019-10-15 14:16:43.354000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             14.9146
# Name: 1856, dtype: object], [time             2019-10-16 11:58:59.331000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 1980, dtype: object, time             2019-10-16 11:59:06.140000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                        0
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                            0.113483
# Name: 1981, dtype: object], [time             2019-10-16 12:43:37.822000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       -1
# room                      OPEN_EXHIBITION_SPACE_2
# time_duration                                   0
# Name: 1992, dtype: object, time             2019-10-16 12:59:22.808000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             15.7498
# Name: 1997, dtype: object, time             2019-10-16 13:14:16.896000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             14.9015
# Name: 2007, dtype: object, time             2019-10-16 13:33:43.181000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             19.4381
# Name: 2012, dtype: object, time             2019-10-16 13:45:32.533000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             11.8225
# Name: 2019, dtype: object, time             2019-10-16 14:00:07.624000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             14.5848
# Name: 2025, dtype: object], [time             2019-10-16 14:30:18.480000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                                   0
# Name: 2036, dtype: object, time             2019-10-16 14:45:07.884000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             14.8234
# Name: 2041, dtype: object, time             2019-10-16 15:00:12.396000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             15.0752
# Name: 2049, dtype: object, time             2019-10-16 15:15:04.348000+08:00
# thermal_cozie                                   9
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             14.8659
# Name: 2057, dtype: object, time             2019-10-16 15:30:04.566000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             15.0036
# Name: 2066, dtype: object], [time             2019-10-17 14:36:16.740000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                        0
# room                                          NaN
# time_duration                                   0
# Name: 2217, dtype: object, time             2019-10-17 14:52:33.805000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             16.2844
# Name: 2219, dtype: object, time             2019-10-17 15:07:39.118000+08:00
# thermal_cozie                                  11
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             15.0885
# Name: 2223, dtype: object, time             2019-10-17 15:33:47.468000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             26.1392
# Name: 2231, dtype: object, time             2019-10-17 15:46:10.944000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             12.3913
# Name: 2234, dtype: object, time             2019-10-17 16:00:53.452000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             14.7085
# Name: 2236, dtype: object, time             2019-10-17 16:20:46.269000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             19.8803
# Name: 2241, dtype: object, time             2019-10-17 16:29:47.552000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             9.02138
# Name: 2244, dtype: object, time             2019-10-17 16:45:07.321000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             15.3295
# Name: 2247, dtype: object, time             2019-10-17 17:07:44.151000+08:00
# thermal_cozie                                  10
# user_id                                   cresh06
# Space_id                                       45
# room                       BUILDING_MATERIALS_LAB
# time_duration                             22.6138
# Name: 2255, dtype: object]]

# %% [markdown]
# # Show how many datapoint are in each cluster after filtering NaN and zero element

# %%
for i in range(len(filtered_cluster_after)):
    print("{0}:{1} ".format(i,(len(filtered_cluster_after[i]))))
# Out:
# 0:3
# 1:9
# 2:7
# 3:4
# 4:2
# 5:6
# 6:5
# 7:10

# %% [markdown]
# # Plot all cluster into one graph

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_after)):
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
        
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot all cluster into separate graphs

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0

for i in range(len(filtered_cluster_after)):
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
    
    plt.figure()
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []

# %% [markdown]
# # Plot test with vertical dotted lines

# %%
# Plot all clusters into ONE graph
thermal = []
duration = []
base = 0.0
dotted_lines = []

for i in range(len(filtered_cluster_after)):
    tempList = []
    for j in range(len(filtered_cluster_after[i])):
        if (j > 1):
            prev = filtered_cluster_after[i][j-1].room
            curr = filtered_cluster_after[i][j].room
            
            if (prev != curr):
                tempList.append(j)
                
    dotted_lines.append(tempList)

#print(dotted_lines)
    
for i in range(len(filtered_cluster_after)):
    lines = []
    for j in range(len(filtered_cluster_after[i])):
        base += filtered_cluster_after[i][j].time_duration
        thermal.append(filtered_cluster_after[i][j].thermal_cozie)
        duration.append(base)
        
    if(len(dotted_lines[i]) > 0):
        while(len(dotted_lines[i]) > 0):
            index = dotted_lines[i].pop()
            xValue = duration[index]
            plt.axvline(x = xValue, linestyle = '--', color = 'r')
        
        
    plt.scatter(duration,thermal)
    plt.plot(duration,thermal)
    plt.xlabel("Duration")
    plt.ylabel("Thermal Cozie")
    plt.yticks(thermal_cozie_ticks)
    plt.show()
    
    #print(filtered_cluster_after[0])
    #print(duration)
    
    # Re-init to remove previous cluster data
    base = 0.0
    thermal = []
    duration = []
